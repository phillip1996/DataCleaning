# %%
# importing dataset
import pandas as pd
df = pd.read_csv('data.csv')
df.head()
# Out:
#            GEO_ID                    NAME  \
# 0              id    Geographic Area Name
# 1  0500000US48001  Anderson County, Texas
# 2  0500000US48003   Andrews County, Texas
# 3  0500000US48005  Angelina County, Texas
# 4  0500000US48007   Aransas County, Texas
#
#                                           DP03_0001E  \
# 0  Estimate!!EMPLOYMENT STATUS!!Population 16 yea...
# 1                                              47868
# 2                                              12916
# 3                                              67561
# 4                                              20752
#
#                                           DP03_0001M  \
# 0  Margin of Error!!EMPLOYMENT STATUS!!Population...
# 1                                                165
# 2                                                203
# 3                                                221
# 4                                                148
#
#                                          DP03_0001PE  \
# ...

# %%
# checking for data shape
df.shape
# Out:
# (255, 550)

# %%
# get good description of the data
df.describe()
# Out:
#        GEO_ID                  NAME  \
# count     255                   255
# unique    255                   255
# top        id  Geographic Area Name
# freq        1                     1
#
#                                                DP03_0001E DP03_0001M  \
# count                                                 255        255
# unique                                                255        172
# top     Estimate!!EMPLOYMENT STATUS!!Population 16 yea...         98
# freq                                                    1          5
#
#                                               DP03_0001PE DP03_0001PM  \
# count                                                 255         255
# unique                                                255           2
# top     Percent Estimate!!EMPLOYMENT STATUS!!Populatio...         (X)
# freq                                                    1         254
#
#        DP03_0002E DP03_0002M DP03_0002PE DP03_0002PM  ... DP03_0135PE  \
# ...

# %%
# checking for missing entries
df.isnull().sum().sum()
# Out:
# 0

# %%
# checking for duplicate records
df.duplicated().sum()
# Out:
# 0

# %%
# removing or droping irrelevant columns
list = ['DP03_0001PM','DP03_0008PM','DP03_0009E','DP03_0009M','DP03_0010PM','DP03_0014PM',
        'DP03_0016PM','DP03_0018PM','DP03_0025PE','DP03_0025PM','DP03_0026PM','DP03_0032PM',
       'DP03_0046PM','DP03_0051PM','DP03_0062PE','DP03_0062PM','DP03_0063PE','DP03_0063PM',
        'DP03_0065PE', 'DP03_0065PM','DP03_0067PE','DP03_0067PM','DP03_0069PE','DP03_0069PM',
        'DP03_0071PE','DP03_0071PM','DP03_0073PE','DP03_0073PM','DP03_0075PM','DP03_0086PE',
        'DP03_0086PM','DP03_0087PE','DP03_0087PM','DP03_0088PE','DP03_0088PM','DP03_0089PM',
        'DP03_0090PE','DP03_0090PM','DP03_0091PE','DP03_0091PM','DP03_0092PE','DP03_0092PE',
        'DP03_0093PE','DP03_0093PM','DP03_0094PE','DP03_0094PM','DP03_0095PM','DP03_0100PM',
        'DP03_0102PM','DP03_0103PM','DP03_0104PM','DP03_0109PM','DP03_0114PM','DP03_0119E',
        'DP03_0119M','DP03_0120E','DP03_0120M','DP03_0121E','DP03_0121M','DP03_0122E','DP03_0122M',
        'DP03_0123E','DP03_0123M','DP03_0124E','DP03_0124M','DP03_0125E','DP03_0125M','DP03_0126E',
        'DP03_0126M','DP03_0127E','DP03_0127M','DP03_0129E','DP03_0129M','DP03_0130E','DP03_0130M',
        'DP03_0131E','DP03_0131M','DP03_0132E','DP03_0132M','DP03_0133E','DP03_0133M','DP03_0134E',
        'DP03_0134M','DP03_0135E','DP03_0135M','DP03_0136E','DP03_0136M','DP03_0137E','DP03_0137M']
df.drop(list, axis =1, inplace = True)

# %%
# dropping first rows(description of header)
list = [0]
df.drop(list, axis = 0, inplace = True)

# %%
# renaming header
df.rename(columns=({ 'NAME': 'CITY'}), inplace=True)

# %%
df.shape
# Out:
# (254, 462)

# %%
df.head()
# Out:
#            GEO_ID                    CITY DP03_0001E DP03_0001M DP03_0001PE  \
# 1  0500000US48001  Anderson County, Texas      47868        165       47868
# 2  0500000US48003   Andrews County, Texas      12916        203       12916
# 3  0500000US48005  Angelina County, Texas      67561        221       67561
# 4  0500000US48007   Aransas County, Texas      20752        148       20752
# 5  0500000US48009    Archer County, Texas       7178         47        7178
#
#   DP03_0002E DP03_0002M DP03_0002PE DP03_0002PM DP03_0003E  ... DP03_0133PE  \
# 1      19877        705        41.5         1.5      19865  ...        12.8
# 2       8625        375        66.8         2.8       8625  ...         9.0
# 3      38913        863        57.6         1.3      38864  ...        15.8
# 4      10919        656        52.6         3.0      10919  ...        18.2
# 5       4550        167        63.4         2.4       4542  ...         7.9
#
# ...

# %%
# replacing some irrelevant entries with zero
df.replace(to_replace =["N", "**","-"], value =0)
# Out:
#              GEO_ID                    NAME DP03_0001E DP03_0001M DP03_0001PE  \
# 1    0500000US48001  Anderson County, Texas      47868        165       47868
# 2    0500000US48003   Andrews County, Texas      12916        203       12916
# 3    0500000US48005  Angelina County, Texas      67561        221       67561
# 4    0500000US48007   Aransas County, Texas      20752        148       20752
# 5    0500000US48009    Archer County, Texas       7178         47        7178
# ..              ...                     ...        ...        ...         ...
# 250  0500000US48499      Wood County, Texas      36277        158       36277
# 251  0500000US48501    Yoakum County, Texas       5975         85        5975
# 252  0500000US48503     Young County, Texas      14211        134       14211
# 253  0500000US48505    Zapata County, Texas      10012        172       10012
# 254  0500000US48507    Zavala County, Texas       9010        161        9010
#
# ...
